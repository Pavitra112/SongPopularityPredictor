# %%
import pandas as pd

# %%
df = pd.read_csv('songs.csv')

# %%
df
# Out:
#      Number                                              title  \
# 0         1                       Put Your Head On My Shoulder
# 1         2  Whatever Will Be Will Be (Que Sera Sera) (with...
# 2         3                           Everybody Loves Somebody
# 3         4        Take Good Care Of My Baby - 1990 Remastered
# 4         5                                 A Teenager In Love
# ..      ...                                                ...
# 662      96                  Stereo Hearts (feat. Adam Levine)
# 663      97                                           Dynamite
# 664      98                                   Break Your Heart
# 665      99                                         Summer Air
# 666     100                                     All I Wanna Do
#
#                   artist        top genre  year  bpm  nrgy  dnce  dB  live  \
# 0              Paul Anka  adult standards  2000  116    34    55  -9    10
# ...

# %%
df.columns
# Out:
# Index(['Number', 'title', 'artist', 'top genre', 'year', 'bpm', 'nrgy', 'dnce',
#        'dB', 'live', 'val', 'dur', 'acous', 'spch', 'pop'],
#       dtype='object')

# %%
# it describe the all data.
df.describe(include='all')
# Out:
#             Number                         title      artist  top genre  \
# count   667.000000                           667         667        651
# unique         NaN                           656         469        115
# top            NaN  Put Your Head On My Shoulder  Elton John  dance pop
# freq           NaN                             2          12        114
# mean     48.718141                           NaN         NaN        NaN
# std      28.414748                           NaN         NaN        NaN
# min       1.000000                           NaN         NaN        NaN
# 25%      24.000000                           NaN         NaN        NaN
# 50%      48.000000                           NaN         NaN        NaN
# 75%      72.000000                           NaN         NaN        NaN
# max     105.000000                           NaN         NaN        NaN
#
#                year         bpm        nrgy        dnce          dB  \
# ...

# %%
# it describe only int and float data.
df.describe(include=['int64','float64'])
# Out:
#            Number         year         bpm        nrgy        dnce  \
# count  667.000000   667.000000  667.000000  667.000000  667.000000
# mean    48.718141  1994.967016  119.121439   61.394303   60.325337
# std     28.414748    17.771374   25.030827   21.703963   15.051583
# min      1.000000  1945.000000   62.000000    6.000000   18.000000
# 25%     24.000000  1980.000000  101.500000   45.000000   51.000000
# 50%     48.000000  1998.000000  120.000000   64.000000   62.000000
# 75%     72.000000  2010.000000  134.000000   79.000000   71.000000
# max    105.000000  2019.000000  199.000000  100.000000   96.000000
#
#                dB        live         val         dur       acous        spch  \
# count  667.000000  667.000000  667.000000  667.000000  667.000000  667.000000
# mean    -8.356822   18.188906   57.311844  224.002999   29.917541    6.179910
# std      3.659509   14.380929   24.400412   59.742591   28.865081    6.191199
# ...

# %%
# it is return the all information of the data.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Number     667 non-null    int64
#  1   title      667 non-null    object
#  2   artist     667 non-null    object
#  3   top genre  651 non-null    object
#  4   year       667 non-null    int64
#  5   bpm        667 non-null    int64
#  6   nrgy       667 non-null    int64
#  7   dnce       667 non-null    int64
#  8   dB         667 non-null    int64
#  9   live       667 non-null    int64
#  10  val        667 non-null    int64
#  11  dur        667 non-null    int64
#  12  acous      667 non-null    int64
#  13  spch       667 non-null    int64
#  14  pop        667 non-null    int64
# dtypes: int64(12), object(3)
# memory usage: 78.3+ KB

# %%
df.isna().sum()
# Out:
# Number        0
# title         0
# artist        0
# top genre    16
# year          0
# bpm           0
# nrgy          0
# dnce          0
# dB            0
# live          0
# val           0
# dur           0
# acous         0
# spch          0
# pop           0
# dtype: int64

# %%
# year vs popularity  of the song.
import matplotlib.pyplot as plt
plt.scatter(df['year'],df['pop'])
plt.xlabel('Year')
plt.ylabel('Popularity')
plt.title('Year v/s Popularity')
plt.show()

# %%
# year vs live recording of the song
import matplotlib.pyplot as plt
plt.scatter(df['year'],df['live'])
plt.xlabel('Year')
plt.ylabel('Live Recording')
plt.title('Year v/s Live Recording')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['acous'],df['dnce'])
plt.xlabel('acousticness')
plt.ylabel('Danceability')
plt.title('acousticness v/s Danceability')
plt.show()

# %%
df.corr()
# Out:
#           Number      year       bpm      nrgy      dnce        dB      live  \
# Number  1.000000  0.122851  0.030950  0.174730  0.046153  0.042841  0.046433
# year    0.122851  1.000000 -0.020790  0.195329  0.273865  0.422602 -0.001603
# bpm     0.030950 -0.020790  1.000000  0.179329 -0.057710  0.044748  0.009960
# nrgy    0.174730  0.195329  0.179329  1.000000  0.331962  0.702543  0.132563
# dnce    0.046153  0.273865 -0.057710  0.331962  1.000000  0.295534 -0.069818
# dB      0.042841  0.422602  0.044748  0.702543  0.295534  1.000000  0.083423
# live    0.046433 -0.001603  0.009960  0.132563 -0.069818  0.083423  1.000000
# val     0.089254 -0.087055  0.084723  0.405190  0.454714  0.136813  0.060542
# dur     0.058410 -0.099655  0.038277  0.131228  0.053011  0.026851 -0.067533
# acous  -0.074355 -0.241289 -0.175530 -0.665900 -0.382297 -0.504551 -0.056394
# spch   -0.059867  0.193292  0.059116  0.178491  0.207741  0.200195  0.091595
# ...

# %%
df.set_index('Number', inplace=True)
df
# Out:
#                                                     title  \
# Number
# 1                            Put Your Head On My Shoulder
# 2       Whatever Will Be Will Be (Que Sera Sera) (with...
# 3                                Everybody Loves Somebody
# 4             Take Good Care Of My Baby - 1990 Remastered
# 5                                      A Teenager In Love
# ...                                                   ...
# 96                      Stereo Hearts (feat. Adam Levine)
# 97                                               Dynamite
# 98                                       Break Your Heart
# 99                                             Summer Air
# 100                                        All I Wanna Do
#
#                      artist        top genre  year  bpm  nrgy  dnce  dB  live  \
# Number
# 1                 Paul Anka  adult standards  2000  116    34    55  -9    10
# 2                 Doris Day  adult standards  1948  177    34    42 -11    72
# ...

# %% [markdown]
# you've identified duplicate rows, you can remove them from the dataset. In Pandas, you can use the drop_duplicates() method.

# %%
df[df.duplicated()]
# Out:
#                                               title            artist  \
# Number
# 9                      Put Your Head On My Shoulder         Paul Anka
# 25      Take Good Care Of My Baby - 1990 Remastered         Bobby Vee
# 56                        Guilty (feat. Barry Gibb)  Barbra Streisand
# 49                                     Hall of Fame        The Script
#
#               top genre  year  bpm  nrgy  dnce  dB  live  val  dur  acous  \
# Number
# 9       adult standards  2000  116    34    55  -9    10   47  155     75
# 25      adult standards  2011   82    43    49 -12    12   66  151     70
# 56      adult standards  1980  151    43    63 -16    11   95  264     23
# 49          celtic rock  2012   85    87    42  -4    12   63  203      7
#
#         spch  pop
# Number
# 9          3   72
# 25         6   60
# 56         4   67
# 49         6   78

# %%
df = df.drop_duplicates()
df
# Out:
#                                                     title  \
# Number
# 1                            Put Your Head On My Shoulder
# 2       Whatever Will Be Will Be (Que Sera Sera) (with...
# 3                                Everybody Loves Somebody
# 4             Take Good Care Of My Baby - 1990 Remastered
# 5                                      A Teenager In Love
# ...                                                   ...
# 96                      Stereo Hearts (feat. Adam Levine)
# 97                                               Dynamite
# 98                                       Break Your Heart
# 99                                             Summer Air
# 100                                        All I Wanna Do
#
#                      artist        top genre  year  bpm  nrgy  dnce  dB  live  \
# Number
# 1                 Paul Anka  adult standards  2000  116    34    55  -9    10
# 2                 Doris Day  adult standards  1948  177    34    42 -11    72
# ...

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['bpm'],notch=True,widths=0.75)
plt.show()

# %%
def find_outliers(doc,col):
    q1 = doc[col].quantile(0.25)
    q3 = doc[col].quantile(0.75)
    IQR = q3 - q1
    low_limit = q1 - IQR*1.5
    high_limit = q3 + IQR*1.5
    doc = doc.loc[(doc[col]<low_limit)|(doc[col]>high_limit)]
    return doc
find_outliers(df,'bpm')
# Out:
#                                                     title           artist  \
# Number
# 30                                           To The Aisle  The Five Satins
# 97                                  Peppermint Twist Pt.1         Joey Dee
# 57                                           It's A Shame     The Spinners
# 100     Crockett's Theme - From "Miami Vice II" Soundt...       Jan Hammer
# 13                                                Starboy       The Weeknd
#
#                         top genre  year  bpm  nrgy  dnce  dB  live  val  dur  \
# Number
# 30             brill building pop  2008  195    27    32 -10    10   55  166
# 97         australian talent show  2019  199    73    42 -11    73   72  122
# 57                   classic soul  1970  199    64    37 -12    12   71  190
# 100                   jazz fusion  1991  191    39    41 -17    10   40  215
# 13      canadian contemporary r&b  2016  186    59    68  -7    14   49  230
#
#         acous  spch  pop
# Number
# ...

# %%
def remove_outliers(doc,col):
    q1 = doc[col].quantile(0.25)
    q3 = doc[col].quantile(0.75)
    IQR = q3 - q1
    low_limit = q1 - IQR*1.5
    high_limit = q3 + IQR*1.5
    doc = doc.loc[(doc[col]>=low_limit)&(doc[col]<=high_limit)]
    return doc
df1 = remove_outliers(df,'bpm')

# %%
df1
# Out:
#                                                     title  \
# Number
# 1                            Put Your Head On My Shoulder
# 2       Whatever Will Be Will Be (Que Sera Sera) (with...
# 3                                Everybody Loves Somebody
# 4             Take Good Care Of My Baby - 1990 Remastered
# 5                                      A Teenager In Love
# ...                                                   ...
# 96                      Stereo Hearts (feat. Adam Levine)
# 97                                               Dynamite
# 98                                       Break Your Heart
# 99                                             Summer Air
# 100                                        All I Wanna Do
#
#                      artist        top genre  year  bpm  nrgy  dnce  dB  live  \
# Number
# 1                 Paul Anka  adult standards  2000  116    34    55  -9    10
# 2                 Doris Day  adult standards  1948  177    34    42 -11    72
# ...

# %%
# value of x should always dataframe.
x = df1.drop(['pop','title','artist','top genre','year'],axis=1)
x
# Out:
#         bpm  nrgy  dnce  dB  live  val  dur  acous  spch
# Number
# 1       116    34    55  -9    10   47  155     75     3
# 2       177    34    42 -11    72   78  123     86     4
# 3        81    49    26  -9    34   40  162     81     4
# 4        82    43    49 -12    12   66  151     70     6
# 5        79    38    56  -9    13   62  158     67     3
# ...     ...   ...   ...  ..   ...  ...  ...    ...   ...
# 96       90    80    65  -3    27   80  211      3    10
# 97      120    79    76  -4     3   87  203      0     8
# 98      122    89    67  -5    24   68  185      0     3
# 99      102    75    76  -4     8   49  184      6     7
# 100     112    79    73  -4     7   56  194     16     7
#
# [658 rows x 9 columns]

# %%
# value of y dataframe or array.
y = df1['pop']
y
# Out:
# Number
# 1      72
# 2      62
# 3      61
# 4      60
# 5      60
#        ..
# 96     56
# 97     56
# 98     54
# 99     43
# 100    32
# Name: pop, Length: 658, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=29)

# %%
x_train.shape
# Out:
# (526, 9)

# %%
x_test.shape
# Out:
# (132, 9)

# %%
y_train.shape
# Out:
# (526,)

# %%
y_test.shape
# Out:
# (132,)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)# making equation.
print(lr.coef_) # value of coeficiente (b) in equation.
import numpy as np
print(np.round(lr.coef_))
print(lr.intercept_) # value of intercept (a)
# Out:
# [ 0.01926977 -0.09110784  0.16452147  1.0174426  -0.020846   -0.10480276
#   0.04093382 -0.15302508  0.16218767]
# [ 0. -0.  0.  1. -0. -0.  0. -0.  0.]
# 65.53187410230969

# %%
x.columns
# Out:
# Index(['bpm', 'nrgy', 'dnce', 'dB', 'live', 'val', 'dur', 'acous', 'spch'], dtype='object')

# %%
y_pred = lr.predict(x_test)
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_pred,y_test))
# Out:
# 117.92247537963739

# %% [markdown]
# random_state = 29 mse 99.66683470489299

# %% [markdown]
# db has 9
# bpm 5
# dnce 3
# live 38
# dur 18
# spch 76
# pop 9

# %% [markdown]
# bpm,year,nrgy,dnce,dB,live,val,dur has no outliers
# bpm,dnce,dB,live,dur,spch,pop has outliers
